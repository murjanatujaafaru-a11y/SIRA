# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = r"c:\Users\murja\Desktop\SIRA"
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
from src.data_loader import DataLoader
from src.eda import DataExplorer

# %%
loader = DataLoader()

# %%
df = loader.load_data()

# %%
explorer = DataExplorer()

# %%
explorer.show_missing_values(df)
# Out:
# missing values:
# ['incident_id', 'report_text', 'location', 'reported_by']

# %% [markdown]
# loader = DataLoader()
# explorer = DataEplorer()
# df = loader.load_data()

# %%
df_empty = df[df["report_text"] == ""]
df_empty_count = df_empty.shape[0]
df_empty_count
# Out:
# 0

# %%
explorer.duplicate_rows(df)
# Out:
# 'Number of duplicate rows: 5'

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df =["report_text"]

# %%
# 1. Let's look at the type of data inside the list
print("Type of data:", type(df))
if len(df) > 0:
    print("\nFirst element in the list looks like:")
    print(df[0])
# Out:
# Type of data: <class 'list'>
#
# First element in the list looks like:
# report_text

# %%
import pandas as pd

if isinstance(df, list):
    column_name = df[0]
    data_rows = df[1:]  
    df = pd.DataFrame(data_rows, columns=[column_name])

# 1. Check the total number of rows available
print(f"Total rows in DataFrame: {len(df)}")

# 2. View the first few rows safely using .head() instead of .loc
print("\nFirst few rows of your data:")
print(df.head())
# Out:
# Total rows in DataFrame: 0
#
# First few rows of your data:
# Empty DataFrame
# Columns: [report_text]
# Index: []

# %%
df
# Out:
#     incident_id                                        report_text  \
# 0             1              Pressure leak detected on Pipeline 7.
# 1             2             Worker slipped near drilling platform.
# 2             3                      Gas detector triggered alarm.
# 3             4        Small oil spill observed near storage tank.
# 4             5  Emergency shutdown initiated after abnormal vi...
# 5             1              Pressure leak detected on Pipeline 7.
# 6             2             Worker slipped near drilling platform.
# 7             3                      Gas detector triggered alarm.
# 8             4        Small oil spill observed near storage tank.
# 9             5  Emergency shutdown initiated after abnormal vi...
# 10            6                                                NaN
# 11            7           Pressure leak detected on Pipeline 7.
# 12            8                      gas detector triggered alarm.
# ...

# %%
df.head()
# Out:
#    incident_id                                        report_text    location  \
# 0            1              Pressure leak detected on Pipeline 7.  Pipeline 7
# 1            2             Worker slipped near drilling platform.  Platform A
# 2            3                      Gas detector triggered alarm.     Plant B
# 3            4        Small oil spill observed near storage tank.   Tank Farm
# 4            5  Emergency shutdown initiated after abnormal vi...    Refinery
#
#   reported_by
# 0        John
# 1       Aisha
# 2     Michael
# 3       David
# 4       Grace

# %%
corrections = {
    "triggred": "triggered"
}

# %%
corrections.items()
# Out:
# dict_items([('triggred', 'triggered')])

# %%
for wrong, correct in corrections.items():
    df["report_text"] = df["report_text"].str.replace(
        wrong,
        correct,
        regex=False
    )

# %%
df.head(15)
# Out:
#     incident_id                                        report_text  \
# 0             1              Pressure leak detected on Pipeline 7.
# 1             2             Worker slipped near drilling platform.
# 2             3                      Gas detector triggered alarm.
# 3             4        Small oil spill observed near storage tank.
# 4             5  Emergency shutdown initiated after abnormal vi...
# 5             1              Pressure leak detected on Pipeline 7.
# 6             2             Worker slipped near drilling platform.
# 7             3                      Gas detector triggered alarm.
# 8             4        Small oil spill observed near storage tank.
# 9             5  Emergency shutdown initiated after abnormal vi...
# 10            6                                                NaN
# 11            7           Pressure leak detected on Pipeline 7.
# 12            8                      gas detector triggered alarm.
# ...

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
print(df.head())
# Out:
# report_text    0
# dtype: int64
# 0
# Empty DataFrame
# Columns: [report_text]
# Index: []
